# %%
import pandas as pd
import datetime as dt

# %%
df = pd.read_csv('30DAY.csv')
df = df.round(2)
df['Day'] = pd.to_datetime(df['Day'])
df['Day'] = (df['Day'] - dt.datetime(1970,1,1)).dt.total_seconds() * 1000.0
df.to_csv('google_trends_convert.csv')

# %%
df
# Out:
#              Day  Tesla  Ford  Chevrolet  Rivian
# 0   1.573085e+12      9    64         33       0
# 1   1.573171e+12      9    66         33       0
# 2   1.573258e+12     10    68         35       0
# 3   1.573344e+12      9    65         32       0
# 4   1.573430e+12      9    65         33       0
# 5   1.573517e+12     10    67         33       0
# 6   1.573603e+12     13    66         32       0
# 7   1.573690e+12     11    66         32       0
# 8   1.573776e+12     10    69         33       0
# 9   1.573862e+12     10    75         36       0
# 10  1.573949e+12     10    72         32       0
# 11  1.574035e+12     11    81         32       0
# 12  1.574122e+12     11    74         33       0
# 13  1.574208e+12     11    70         32       0
# 14  1.574294e+12     16    68         33       0
# 15  1.574381e+12    100    72         34       4
# 16  1.574467e+12     71    74         35       2
# 17  1.574554e+12     53    69         31       1
# ...
